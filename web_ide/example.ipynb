# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from simflow import Widget
w = Widget()
w

# %%
w.nodes
# Out:
# [{'id': 'n1',
#   'position': {'x': 0, 'y': 0},
#   'data': {'label': 'Node 1'},
#   'measured': {'width': 150, 'height': 35}},
#  {'id': 'n2',
#   'position': {'x': 0, 'y': 100},
#   'data': {'label': 'Node 2'},
#   'measured': {'width': 150, 'height': 35}}]

# %%
called
# Out:
# False
